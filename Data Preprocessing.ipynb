# %% [markdown]
# # Data Preprocessing
# This notebook is used to preprocess the data (e.g.: extracting golden labels, generating image captions)

# %% [markdown]
# ## Food101

# %%
import pandas as pd
import json
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

# %%
import skimage.io as io
from PIL import Image

# %%
food101_imgpath = 'Food101/food-101/images'
food101_train_json = 'Food101/food-101/meta/train.json'
food101_test_json = 'Food101/food-101/meta/test.json'

# %%
import json

with open(food101_train_json, 'r') as f:
    train_data_ann = json.load(f)

with open(food101_test_json, 'r') as f:
    test_data_ann = json.load(f)

print("Number of classes in train and test dataset")
print(len(train_data_ann.keys()))
print(len(test_data_ann.keys()))

print("Number of images in train and test dataset")
num_train = 0
num_test = 0

for k in train_data_ann.keys():
    num_train += len(train_data_ann[k])

for k in test_data_ann.keys():
    num_test += len(test_data_ann[k])

print(num_train)
print(num_test)
# Out:
# Number of classes in train and test dataset
# 101
# 101
# Number of images in train and test dataset
# 75750
# 25250

# %%
# What is stored in the ann file:
print(train_data_ann.keys())
print(test_data_ann['churros'])
# Out:
# dict_keys(['churros', 'hot_and_sour_soup', 'samosa', 'sashimi', 'pork_chop', 'spring_rolls', 'panna_cotta', 'beef_tartare', 'greek_salad', 'foie_gras', 'tacos', 'pad_thai', 'poutine', 'ramen', 'pulled_pork_sandwich', 'bibimbap', 'beignets', 'apple_pie', 'crab_cakes', 'risotto', 'paella', 'steak', 'baby_back_ribs', 'miso_soup', 'frozen_yogurt', 'club_sandwich', 'carrot_cake', 'falafel', 'bread_pudding', 'chicken_wings', 'gnocchi', 'caprese_salad', 'creme_brulee', 'escargots', 'chocolate_cake', 'tiramisu', 'spaghetti_bolognese', 'mussels', 'scallops', 'baklava', 'edamame', 'macaroni_and_cheese', 'pancakes', 'garlic_bread', 'beet_salad', 'onion_rings', 'red_velvet_cake', 'grilled_salmon', 'chicken_curry', 'deviled_eggs', 'caesar_salad', 'hummus', 'fish_and_chips', 'lasagna', 'peking_duck', 'guacamole', 'strawberry_shortcake', 'clam_chowder', 'croque_madame', 'french_onion_soup', 'beef_carpaccio', 'fried_rice', 'donuts', 'gyoza', 'ravioli', 'fried_calamari', 'spaghetti_carbonara', 'french_toast', 'lobster_bisque', 'ceviche', 'bruschetta', 'french_fries', 'shrimp_and_grits', 'filet_mignon', 'hamburger', 'dumplings', 'tuna_tartare', 'sushi', 'cheese_plate', 'eggs_benedict', 'cup_cakes', 'takoyaki', 'chocolate_mousse', 'breakfast_burrito', 'hot_dog', 'macarons', 'waffles', 'seaweed_salad', 'cannoli', 'huevos_rancheros', 'pizza', 'chicken_quesadilla', 'pho', 'prime_rib', 'cheesecake', 'ice_cream', 'omelette', 'grilled_cheese_sandwich', 'lobster_roll_sandwich', 'nachos', 'oysters'])
# ['churros/1061830', 'churros/1064042', 'churros/1074903', 'churros/1085259', 'churros/1097261', 'churros/1099137', 'churros/1105308', 'churros/1121931', 'churros/1130533', 'churros/1142581', 'churros/1148015', 'churros/1157589', 'churros/1162376', 'churros/1168179', 'churros/1173613', 'churros/1183750', 'churros/1213663', 'churros/1214695', 'churros/1235914', 'churros/1239292', 'churros/1251291', 'churros/125886', 'churros/127590', 'churros/1286743', 'churros/1294048', 'churros/1348657', 'churros/137086', 'churros/1420399', 'churros/1501410', 'churros/1502733', 'churros/1503591', 'churros/1560770', 'churros/1562038', 'churros/1564939', 'churros/1572415', 'churros/1630055', 'churros/1634185', 'churros/1673820', 'churros/1681026', 'churros/1683636', 'churros/1683772', 'churros/1688402', 'churros/1709019', 'churros/1728462', 'churros/1730900', 'churros/1731067', 'churros/1736177', 'churros/1737797', 'churros/1751757', 'churros/1766438', 'churros/1797535', 'churros/1816647', 'churros/1840475', 'churros/1855779', 'churros/1859877', 'churros/1881699', 'churros/1904318', 'churros/1931612', 'churros/1939241', 'churros/1975148', 'churros/1980483', 'churros/199032', 'churros/2015378', 'churros/2031930', 'churros/2037510', 'churros/2041073', 'churros/2055280', 'churros/2059542', 'churros/2074713', 'churros/2112924', 'churros/2146131', 'churros/2149879', 'churros/2157712', 'churros/2186665', 'churros/2188772', 'churros/2236356', 'churros/2255673', 'churros/2261310', 'churros/2264940', 'churros/2270485', 'churros/2297235', 'churros/230131', 'churros/2307498', 'churros/2315601', 'churros/2360308', 'churros/2371997', 'churros/2376955', 'churros/238429', 'churros/2399421', 'churros/2403548', 'churros/2410744', 'churros/245301', 'churros/2484407', 'churros/2489040', 'churros/2509088', 'churros/2522264', 'churros/2526456', 'churros/2537428', 'churros/254472', 'churros/2545695', 'churros/2546790', 'churros/255168', 'churros/2555793', 'churros/2562650', 'churros/256560', 'churros/2601843', 'churros/2604351', 'churros/2610912', 'churros/2617186', 'churros/2618045', 'churros/2623176', 'churros/2663394', 'churros/2697646', 'churros/2698148', 'churros/2702990', 'churros/2707980', 'churros/2708222', 'churros/2722631', 'churros/2735230', 'churros/274692', 'churros/2748152', 'churros/275341', 'churros/2763955', 'churros/2783537', 'churros/2791225', 'churros/2807096', 'churros/2813469', 'churros/2922132', 'churros/2987007', 'churros/3006013', 'churros/3008612', 'churros/3018761', 'churros/3026751', 'churros/3029897', 'churros/3047939', 'churros/3058558', 'churros/3070093', 'churros/3072744', 'churros/3077911', 'churros/3097216', 'churros/3097712', 'churros/3103265', 'churros/3104514', 'churros/3111770', 'churros/3168659', 'churros/3180897', 'churros/3205589', 'churros/3227551', 'churros/3236111', 'churros/3247092', 'churros/3268704', 'churros/3297337', 'churros/3303373', 'churros/3303522', 'churros/3305924', 'churros/3306440', 'churros/3308027', 'churros/3323014', 'churros/3334959', 'churros/3344684', 'churros/3344709', 'churros/3353827', 'churros/3357193', 'churros/3369165', 'churros/3417372', 'churros/3417598', 'churros/3429460', 'churros/3430758', 'churros/3431478', 'churros/3431480', 'churros/3438481', 'churros/3453323', 'churros/3479518', 'churros/348715', 'churros/3506336', 'churros/3513246', 'churros/3528308', 'churros/3531551', 'churros/3546196', 'churros/3555428', 'churros/3581080', 'churros/3593258', 'churros/3593479', 'churros/3641322', 'churros/3673129', 'churros/3693400', 'churros/3698417', 'churros/3700970', 'churros/3716210', 'churros/3781999', 'churros/3799876', 'churros/3809327', 'churros/3819477', 'churros/3835021', 'churros/384446', 'churros/3847691', 'churros/3853943', 'churros/3855783', 'churros/3882299', 'churros/3882570', 'churros/3905690', 'churros/439764', 'churros/450253', 'churros/454763', 'churros/456796', 'churros/467000', 'churros/471940', 'churros/476828', 'churros/498323', 'churros/499620', 'churros/509888', 'churros/51483 ...

# %%
for churros in test_data_ann['churros'][:10]:
    print(io.imread(f'Food101/food-101/images/{churros}.jpg'))
# Out:
# [[[203 239 253]
#   [205 241 255]
#   [207 243 255]
#   ...
#   [ 71  80 137]
#   [ 73  79 137]
#   [ 77  83 141]]
#
#  [[203 239 253]
#   [204 240 254]
#   [205 241 255]
#   ...
#   [ 75  84 141]
#   [ 78  84 142]
#   [ 81  87 145]]
#
#  [[203 239 253]
#   [203 239 253]
#   [202 238 252]
#   ...
#   [ 77  87 146]
#   [ 79  88 147]
#   [ 82  91 150]]
#
#  ...
#
#  [[229 220 225]
#   [228 219 224]
#   [226 220 222]
#   ...
#   [ 44  61 105]
#   [ 42  57 100]
#   [ 41  54  98]]
#
#  [[222 216 228]
#   [223 217 229]
#   [224 218 230]
#   ...
#   [ 48  68 119]
#   [ 45  63 113]
#   [ 44  60 109]]
#
#  [[238 234 249]
#   [239 235 250]
#   [241 237 252]
#   ...
#   [ 53  74 129]
#   [ 49  69 122]
#   [ 48  65 117]]]
# [[[187 105   3]
#   [188 106   4]
#   [188 106   6]
#   ...
#   [100  47   3]
#   [101  48   4]
#   [101  48   4]]
#
#  [[188 106   4]
#   [190 108   6]
#   [191 109   9]
#   ...
#   [ 99  46   2]
#   [100  47   3]
#   [101  48   4]]
#
#  [[187 106   1]
#   [188 107   2]
#   [188 109   6]
#   ...
#   [ 98  45   1]
#   [ 99  46   2]
#   [100  47   3]]
#
#  ...
#
#  [[174 108  11]
#   [163  98   0]
#   [162  97   0]
#   ...
#   [108  52   5]
#   [109  51   5]
#   [103  45   0]]
#
#  [[174 110  10]
#   [169 105   5]
#   [170 106   6]
#   ...
#   [109  51   5]
#   [112  54   8]
#   [107  49   3]]
#
#  [[161  97   0]
#   [173 109   9]
#   [176 113  10]
#   ...
#   [110  52   6]
#   [113  55   9]
#   [110  52   6]]]
# [[[ 94  94  94]
#   [ 90  90  90]
#   [ 85  87  86]
#   ...
#   [111 121 120]
#   [128 138 137]
#   [128 138 137]]
#
#  [[ 89  89  89]
#   [ 88  88  88]
#   [ 84  86  85]
#   ...
#   [118 128 127]
#   [125 135 134]
#   [125 135 134]]
#
#  [[ 91  91  91]
#   [ 93  93  93]
#   [ 90  92  91]
#   ...
#   [134 144 143]
#   [126 136 135]
#   [127 137 136]]
#
#  ...
#
#  [[ 49  67  71]
#   [ 48  66  70]
#   [ 55  68  76]
#   ...
#   [140 162 175]
#   [134 156 170]
#   [122 144 158]]
#
#  [[ 52  70  74]
#   [ 43  61  65]
#   [ 58  71  79]
#   ...
#   [124 143 158]
#   [135 157 171]
#   [136 158 172]]
#
#  [[ 59  77  81]
#   [ 47  65  69]
#   [ 74  87  95]
#   ...
#   [ 80  99 114]
#   [125 147 161]
#   [141 163 177]]]
# [[[139  67   0]
#   [149  77   5]
#   [160  88  16]
#   ...
#   [165 100  10]
#   [165  99  12]
#   [160  94   7]]
#
#  [[150  78   6]
#   [155  83  11]
#   [159  87  15]
#   ...
#   [162  97   7]
#   [166 100  13]
#   [162  96   9]]
#
#  [[152  80   6]
#   [157  85  11]
#   [154  85  10]
#   ...
#   [167 102  10]
#   [176 111  21]
#   [171 106  16]]
#
#  ...
#
#  [[115  61  17]
#   [119  65  21]
#   [116  62  18]
#   ...
#   [126  68  18]
#   [123  67  18]
#   [123  67  18]]
#
#  [[117  65  18]
#   [120  68  21]
#   [115  63  16]
#   ...
#   [117  59  11]
#   [118  62  15]
#   [114  58  11]]
#
#  [[104  52   5]
#   [107  55   8]
#   [104  52   5]
#   ...
#   [119  61  13]
#   [122  66  19]
#   [114  58  11]]]
# [[[131  59   1]
#   [132  60   2]
#   [131  61   2]
#   ...
#   [255 249 233]
#   [255 248 233]
#   [255 248 233]]
#
#  [[130  58   0]
#   [131  59   1]
#   [130  60   1]
#   ...
#   [255 249 233]
#   [255 247 232]
#   [255 247 232]]
#
#  [[131  59   1]
#   [131  59   1]
#   [131  59   1]
#   ...
#   [255 249 233]
#   [255 247 232]
#   [255 246 231]]
#
#  ...
#
#  [[158 104  76]
#   [157 103  75]
#   [157 103  75]
#   ...
#   [ 73  74  76]
#   [ 72  73  75]
#   [ 72  73  75]]
#
#  [[158 104  76]
#   [158 104  76]
#   [157 103  75]
#   ...
#   [ 73  74  76]
#   [ 72  73  75]
#   [ 72  73  75]]
#
#  [[159 105  77]
#   [158 104  76]
#   [157 103  75]
#   ...
#   [ 72  73  75]
#   [ 72  73  75]
#   [ 72  73  75]]]
# [[[205 217 207]
#   [200 212 200]
#   [201 213 199]
#   ...
#   [178 148  26]
#   [177 146  29]
#   [184 153  36]]
#
#  [[214 224 213]
#   [208 220 206]
#   [198 211 194]
#   ...
#   [194 164  44]
#   [194 163  46]
#   [192 161  44]]
#
#  [[218 226 211]
#   [214 225 208]
#   [201 213 193]
#   ...
#   [195 166  48]
#   [200 171  53]
#   [201 172  54]]
#
#  ...
#
#  [[196 185  77]
#   [199 188  80]
#   [197 187  76]
#   ...
#   [238 240 177]
#   [236 238 175]
#   [241 243 180]]
#
#  [[184 173  67]
#   [188 177  69]
#   [191 181  70]
#   ...
#   [235 237 174]
#   [230 232 169]
#   [232 234 171]]
#
#  [[204 193  87]
#   [200 189  81]
#   [195 184  76]
#   ...
#   [231 233 170]
#   [227 229 166]
#   [231 233 170]]]
# [[[100 101  96]
#   [101 102  97]
#   [100 101  96]
#   ...
#   [ 55  51  40]
#   [ 54  52  40]
#   [ 54  52  40]]
#
#  [[102 103  98]
#   [104 105 100]
#   [105 106 101]
#   ...
#   [ 54  50  39]
#   [ 53  51  39]
#   [ 52  50  38]]
#
#  [[102 103  98]
#   [106 107 102]
#   [109 110 105]
#   ...
#   [ 55  51  42]
#   [ 55  51  42]
#   [ 56  52  43]]
#
#  ...
#
#  [[187 193 181]
#   [188 194 182]
#   [190 196 184]
#   ...
#   [ 88  89  84]
#   [ 83  84  79]
#   [ 78  79  74]]
#
#  [[186 192 180]
#   [187 193 181]
#   [189 195 183]
#   ...
#   [ 74  74  72]
#   [ 69  69  67]
#   [ 65  65  63]]
#
#  [[186 192 180]
#   [187 193 181]
#   [189 195 183]
#   ...
#   [ 66  66  64]
#   [ 74  74  72]
#   [ 80  80  78]]]
# [[[ 86  29  10]
#   [ 83  26   7]
#   [ 81  23   3]
#   ...
#   [108  76  38]
#   [103  71  33]
#   [ 99  67  29]]
#
#  [[ 83  24   6]
#   [ 82  24   4]
#   [ 82  24   4]
#   ...
#   [100  67  32]
#   [ 97  64  31]
#   [ 93  60  25]]
#
#  [[ 82  21   2]
#   [ 84  23   4]
#   [ 86  25   6]
#   ...
#   [ 83  52  23]
#   [ 83  52  24]
#   [ 81  50  21]]
#
#  ...
#
#  [[112  49  14]
#   [ 99  39   5]
#   [105  44  13]
#   ...
#   [232 228 183]
#   [234 229 187]
#   [236 231 189]]
#
#  [[ 97  37   3]
#   [106  46  12]
#   [110  51  19]
#   ...
#   [231 226 184]
#   [234 229 187]
#   [237 232 192]]
#
#  [[ 95  35   1]
#   [102  43   9]
#   [ 92  33   3]
#   ...
#   [231 226 184]
#   [233 228 188]
#   [236 231 191]]]
# [[[22 22 30]
#   [22 22 30]
#   [22 22 30]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[17 17 25]
#   [17 17 25]
#   [16 16 24]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[11 10 16]
#   [11 10 16]
#   [11 10 16]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  ...
#
#  [[ 4  4  4]
#   [ 4  4  4]
#   [ 4  4  4]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 4  4  4]
#   [ 4  4  4]
#   [ 3  3  3]
#   ...
#   [ 1  1  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 4  4  4]
#   [ 3  3  3]
#   [ 3  3  3]
#   ...
#   [ 1  1  0]
#   [ 1  1  0]
#   [ 0  0  0]]]
# [[[ 60  42  30]
#   [ 60  42  30]
#   [ 62  42  31]
#   ...
#   [ 82  56  39]
#   [ 81  55  38]
#   [ 81  55  38]]
#
#  [[ 60  42  30]
#   [ 60  42  30]
#   [ 62  42  31]
#   ...
#   [ 82  56  39]
#   [ 81  55  38]
#   [ 80  54  37]]
#
#  [[ 59  41  29]
#   [ 59  41  29]
#   [ 61  41  30]
#   ...
#   [ 81  56  36]
#   [ 80  55  35]
#   [ 79  54  34]]
#
#  ...
#
#  [[183 149 112]
#   [183 149 112]
#   [184 150 113]
#   ...
#   [204 180 142]
#   [204 180 142]
#   [205 181 143]]
#
#  [[183 149 111]
#   [182 148 110]
#   [182 148 110]
#   ...
#   [204 180 142]
#   [204 180 142]
#   [204 182 143]]
#
#  [[181 147 109]
#   [180 146 108]
#   [180 146 108]
#   ...
#   [204 180 142]
#   [203 181 142]
#   [204 182 143]]]

# %%
# Check an actual image
img = Image.open(f'{os.path.join(food101_imgpath, 'samosa/1027474.jpg')}')
img.show()

# %% [markdown]
# #### Create new annotations with captions
#
# annotation format: <br>
# {<br>
#   image_id (name of image without .jpg): <br>
#       { <br>
#     'label': the image category, <br>
#     'filepath': the filepath of the image <br>
#     'caption': generated caption to describe the image <br>
#    } <br>
#    ...<br>
# }

# %%
train_full_annotation = dict()

for label, filepaths in train_data_ann.items():
    for filepath in filepaths:
        img_id = filepath.replace(f"{label}/", "")
        img_id = int(img_id)

        train_full_annotation[img_id] = {
            "img_id": img_id,
            "label": label,
            "filepath": f"{food101_imgpath}/{filepath}.jpg",
            "caption": None
        }

# %%
test_full_annotation = dict()

for label, filepaths in test_data_ann.items():
    for filepath in filepaths:
        img_id = filepath.replace(f"{label}/", "")
        img_id = int(img_id)
        
        test_full_annotation[img_id] = {
            "img_id": img_id,
            "label": label,
            "filepath": f"{food101_imgpath}/{filepath}.jpg",
            "caption": None
        }

# %%
for example_img in [k for k in train_full_annotation.keys()][:10]:
    print(train_full_annotation[example_img])
# Out:
# {'img_id': 1004234, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1004234.jpg', 'caption': None}
# {'img_id': 1013460, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1013460.jpg', 'caption': None}
# {'img_id': 1016791, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1016791.jpg', 'caption': None}
# {'img_id': 102100, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/102100.jpg', 'caption': None}
# {'img_id': 1025494, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1025494.jpg', 'caption': None}
# {'img_id': 1029245, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1029245.jpg', 'caption': None}
# {'img_id': 1029669, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1029669.jpg', 'caption': None}
# {'img_id': 1031729, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1031729.jpg', 'caption': None}
# {'img_id': 1037793, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1037793.jpg', 'caption': None}
# {'img_id': 1062354, 'label': 'churros', 'filepath': 'Food101/food-101/images/churros/1062354.jpg', 'caption': None}

# %%
print(len(train_full_annotation))
print(len(test_full_annotation))
# Out:
# 75750
# 25250

# %%
json.dump(train_full_annotation, open('Food101/food-101/meta/train_full_annotation.json', 'w'))
json.dump(test_full_annotation, open('Food101/food-101/meta/test_full_annotation.json', 'w'))

# %% [markdown]
# #### Generate captions for each image

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
